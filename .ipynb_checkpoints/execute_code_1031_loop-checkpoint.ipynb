# %% [markdown]
# # import & 関数定義

# %%
import os, sys, math, time, winsound, random, h5py, datetime, serial, itertools
import numpy as np, pandas as pd, seaborn as sns, tensorflow as tf
# from matplotlib import pyplot as plt
from tensorflow import keras
from keras.models import model_from_json
from tensorflow.keras import layers
from scipy import stats
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from IPython.display import clear_output
import my_module as mm
from sklearn.metrics import accuracy_score

os.makedirs("model_files", exist_ok=True)

# %%
def append(name):
    name_list.append(name)

# %%
def send(datalist, print_data=False):
    for i in range(len(datalist)):
        if datalist[i]<0:
            datalist[i]=abs(datalist[i])
            datalist[i]+=128
        else:
            datalist[i]=abs(datalist[i])
        if print_data:
            print(datalist[i])
    if serial_flag:
        ser.write(bytes(datalist))

# %% [markdown]
# # パラメータ設定

# %%
weight_per_depth = 0.01 ### 重みの変化量に対するdepthの変化量(1/m)
depth_per_sec = 0.005### ソレノイド開放時間に対する砂山のdepth変化量(m/sec)
serial_flag=False

# %%
if serial_flag:
    ser = serial.Serial("COM9", 9600)

# %% [markdown]
# # 初期化

# %% [markdown]
# ## NN構築

# %%
x_train, y_train, x_test, y_test = mm.make_dataset(1000, 5)

# %%
model_initial = keras.models.Sequential([
#   layers.Dense(3, activation='tanh'),
  layers.Dense(3, activation='tanh'),
  layers.Dense(2, activation='tanh'),
  layers.Dense(2, activation='tanh')
])
predictions = model_initial(np.array(x_train)[:1]).numpy()
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model_initial.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])
model_initial.fit(x_train, y_train, epochs=100, verbose=0)
model_initial.evaluate(x_test, y_test)
test_result_2=pd.concat([x_test, y_test, pd.Series(np.argmax(model_initial.predict(x_test, verbose=0), axis = 1), name="predict")], axis=1)
sns.jointplot(x='x', y='y', data=test_result_2, hue="predict", marker="o")
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.8152

# %%
model_initial.save_weights("model_files/weight.hdf5")
model_initial.save_weights("model_files/weight_init.hdf5")
with open("model_files/model.json", 'w') as f:
    f.write(model_initial.to_json())

# %%
name_list=[]
data={}
with h5py.File("model_files/weight.hdf5",'r+') as f:
    f.visit(append)
    for name in name_list:
        if isinstance(f[name], h5py.Dataset):        
            data[name]=f[name][()]

# %%
parameter_count=0
for i in list(data):
    print(data[i], data[i].shape)
    if len(data[i].shape)>1:
        parameter_count+=data[i].shape[0]*data[i].shape[1]
    else:
        parameter_count+=data[i].shape[0]
print("parameter count:", parameter_count)
# Out:
# [ 0.79606307  0.7394114  -0.84067035] (3,)
# [[-0.51425296 -0.419236   -0.19346535]
#  [-0.9550995   0.06361902 -0.36660066]
#  [ 0.12342438  0.3625921  -0.48831707]
#  [ 0.63616216  0.6037027   0.34912068]] (4, 3)
# [-0.0195611   0.43925366] (2,)
# [[-0.8564454  -0.7562943 ]
#  [ 0.61134315 -0.56691486]
#  [ 0.97420996  0.51152384]] (3, 2)
# [-0.24107818  0.32048336] (2,)
# [[-1.2979858  -0.26862907]
#  [-0.8356944   1.8293115 ]] (2, 2)
# parameter count: 29

# %% [markdown]
# ## Depth初期化

# %%
while True:
    try:
        depth_init=pd.read_csv("model_files/depth_info.csv", header=None)
    except:
        pass
    else:
        break
depth_init.to_csv("model_files/depth_initial.csv", header=None, index=None)

# %%
depth_init
# Out:
#          0        1        2         3        4         5
# 0  1.52100  1.52522  1.52411  1.511220  1.50089  1.527220
# 1  1.40489  1.55011  1.53033  0.000000  1.52725  1.519440
# 2  1.54822  1.56444  0.00000  0.317889  0.26320  1.549670
# 3  1.57256  1.55689  0.49300  0.337000  0.26300  1.535440
# 4  1.55222  1.56589  1.04467  0.368500  0.26200  0.000000
# 5  1.58122  1.56433  1.55967  0.000000  0.27620  0.411167

# %%
model=tf.keras.models.model_from_json(open("model_files/model.json", "r").read())
model.load_weights("model_files/weight.hdf5")
model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

# %% [markdown]
# # Loop部

# %%
while True:

    model.fit(x_train, y_train, epochs=1, verbose=0)

    name_list=[]
    weight_previous={}
    with h5py.File("model_files/weight.hdf5",'r+') as f:
        f.visit(append)
        for name in name_list:
            if isinstance(f[name], h5py.Dataset):        
                weight_previous[name]=f[name][()]

    model.save_weights("model_files/weight.hdf5")

    name_list=[]
    weight_current={}
    with h5py.File("model_files/weight.hdf5",'r+') as f:
        f.visit(append)
        for name in name_list:
            if isinstance(f[name], h5py.Dataset):        
                weight_current[name]=f[name][()]

    weight_change={}
    weight_change_list=[]
    for item in weight_current:
        change=weight_current[item] - weight_previous[item]
        if len(change.shape)==1:
                list_item=change
        else:
            list_item=list(itertools.chain.from_iterable(change))
        weight_change_list.extend(list_item)
        weight_change[item] = weight_current[item] - weight_previous[item]

    sec_list=weight_change_list.copy()
    for i in range(len(weight_change_list)):
        sec_list[i]=int(weight_change_list[i]/weight_per_depth/depth_per_sec)
        if sec_list[i]>127:
            sec_list[i]=127
        if sec_list[i]<-127:
            sec_list[i]=-127
    sec_list.append(128) # End

    send(sec_list, print_data=False)

    while True:
        try:
            depth_current=pd.read_csv("model_files/depth_info.csv", header=None)
        except:
            pass
        else:
            break

    weight_matrix=(depth_current-depth_init)*weight_per_depth

    new_weight_list=list(itertools.chain.from_iterable(weight_matrix.values.tolist()))

    name_list=[]
    stored_count=0
    with h5py.File("model_files/weight.hdf5",'r+') as f:
        f.visit(append)
        for name in name_list:
            if isinstance(f[name], h5py.Dataset):
                if len(data[name].shape)==1: # bias
                    for x in range(data[name].shape[0]):
                        data[name][x]=new_weight_list[stored_count]
                        stored_count+=1
                elif len(data[name].shape)==2: # weight
                    for x in range(data[name].shape[0]):
                        for y in range(data[name].shape[1]):
                            data[name][x][y]=new_weight_list[stored_count]
                            stored_count+=1
                else: #?
                    raise UserWarning("length>3")
                f[name][()]=data[name]
    name_list=[]
    weight_previous={}
    with h5py.File("model_files/weight.hdf5",'r+') as f:
        f.visit(append)
        for name in name_list:
            if isinstance(f[name], h5py.Dataset):        
                weight_previous[name]=f[name][()]
    print(weight_previous)

    model=tf.keras.models.model_from_json(open("model_files/model.json", "r").read())
    model.load_weights("model_files/weight.hdf5")
    model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])

    model.evaluate(x_test, y_test)
    test_result=pd.concat([x_test, y_test, pd.Series(np.argmax(model.predict(x_test, verbose=0), axis = 1), name="predict")], axis=1)
    print(datetime.datetime.now().isoformat())
    print("accuracy:", accuracy_score(test_result["class"], test_result["predict"]))
#     sns.jointplot(x='x', y='y', data=test_result, hue="predict", marker="o")


    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 while True:
# ----> 3     model.fit(x_train, y_train, epochs=1, verbose=0)
#       5     name_list=[]
#       6     weight_previous={}
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2452, in Function.__call__(self, *args, **kwargs)
#    2449 """Calls a graph function specialized to the inputs."""
#    2450 with self._lock:
#    2451   (graph_function,
# -> 2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:1116, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1114 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1115 try:
# -> 1116   return autograph.converted_call(
#    1117       original_func,
#    1118       args,
#    1119       kwargs,
#    1120       options=autograph.ConversionOptions(
#    1121           recursive=True,
#    1122           optional_features=autograph_options,
#    1123           user_requested=True,
#    1124       ))
#    1125 except Exception as e:  # pylint:disable=broad-except
#    1126   if hasattr(e, "ag_error_metadata"):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filejf88cjvu.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1040, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1037   run_step = tf.function(
#    1038       run_step, jit_compile=True, reduce_retracing=True)
#    1039 data = next(iterator)
# -> 1040 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1041 outputs = reduce_per_replica(
#    1042     outputs, self.distribute_strategy, reduction='first')
#    1043 return outputs
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1030, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1029 def run_step(data):
# -> 1030   outputs = model.train_step(data)
#    1031   # Ensure counter is updated only if `train_step` succeeds.
#    1032   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:893, in Model.train_step(self, data)
#     891 self._validate_target_and_loss(y, loss)
#     892 # Run backwards pass.
# --> 893 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     894 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:537, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     506 def minimize(self, loss, var_list, grad_loss=None, name=None, tape=None):
#     507   """Minimize `loss` by updating `var_list`.
#     508
#     509   This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     535
#     536   """
# --> 537   grads_and_vars = self._compute_gradients(
#     538       loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#     539   return self.apply_gradients(grads_and_vars, name=name)
#
# File ~\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:590, in OptimizerV2._compute_gradients(self, loss, var_list, grad_loss, tape)
#     588 var_list = tf.nest.flatten(var_list)
#     589 with tf.name_scope(self._name + "/gradients"):
# --> 590   grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     592 self._assert_valid_dtypes([
#     593     v for g, v in grads_and_vars
#     594     if g is not None and v.dtype != tf.resource
#     595 ])
#     597 return grads_and_vars
#
# File ~\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:471, in OptimizerV2._get_gradients(self, tape, loss, var_list, grad_loss)
#     469 def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     470   """Called in `minimize` to compute gradients from loss."""
# --> 471   grads = tape.gradient(loss, var_list, grad_loss)
#     472   return list(zip(grads, var_list))
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py:1100, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1094   output_gradients = (
#    1095       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1096           output_gradients))
#    1097   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1098                       for x in output_gradients]
# -> 1100 flat_grad = imperative_grad.imperative_grad(
#    1101     self._tape,
#    1102     flat_targets,
#    1103     flat_sources,
#    1104     output_gradients=output_gradients,
#    1105     sources_raw=flat_sources_raw,
#    1106     unconnected_gradients=unconnected_gradients)
#    1108 if not self._persistent:
#    1109   # Keep track of watched variables before setting tape to None
#    1110   self._watched_variables = self._tape.watched_variables()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py:157, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155     gradient_name_scope += forward_pass_name_scope + "/"
#     156   with ops.name_scope(gradient_name_scope):
# --> 157     return grad_fn(mock_op, *out_grads)
#     158 else:
#     159   return grad_fn(mock_op, *out_grads)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1488, in _DivNoNanGrad(op, grad)
#    1481 x = math_ops.conj(x)
#    1482 y = math_ops.conj(y)
#    1483 return (
#    1484     array_ops.reshape(
#    1485         math_ops.reduce_sum(math_ops.div_no_nan(grad, y), rx), sx),
#    1486     array_ops.reshape(
#    1487         math_ops.reduce_sum(
# -> 1488             grad * math_ops.div_no_nan(math_ops.div_no_nan(-x, y), y),  # pylint: disable=invalid-unary-operand-type
#    1489             ry),
#    1490         sy))
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:1655, in div_no_nan(x, y, name)
#    1653 x = ops.convert_to_tensor(x, name="x")
#    1654 y = ops.convert_to_tensor(y, name="y", dtype=x.dtype.base_dtype)
# -> 1655 return gen_math_ops.div_no_nan(x, y, name=name)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:3243, in div_no_nan(x, y, name)
#    3241     pass  # Add nodes to the TensorFlow graph.
#    3242 # Add nodes to the TensorFlow graph.
# -> 3243 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3244       "DivNoNan", x=x, y=y, name=name)
#    3245 _result = _outputs[:]
#    3246 if _execute.must_record_gradient():
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py:694, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     692   inp = self.capture(inp)
#     693   captured_inputs.append(inp)
# --> 694 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     695     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     696     compute_device)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:3754, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3751 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3752 # Session.run call cannot occur between creating and mutating the op.
#    3753 with self._mutation_lock():
# -> 3754   ret = Operation(
#    3755       node_def,
#    3756       self,
#    3757       inputs=inputs,
#    3758       output_types=dtypes,
#    3759       control_inputs=control_inputs,
#    3760       input_types=input_types,
#    3761       original_op=self._default_original_op,
#    3762       op_def=op_def)
#    3763   self._create_op_helper(ret, compute_device=compute_device)
#    3764 return ret
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:2129, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2127   if op_def is None:
#    2128     op_def = self._graph._get_op_def(node_def.op)
# -> 2129   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2130                             control_input_ops, op_def)
#    2131   name = compat.as_str(node_def.name)
#    2133 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1933, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1931 inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#    1932 # pylint: disable=protected-access
# -> 1933 op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1934                                             compat.as_str(node_def.op),
#    1935                                             compat.as_str(node_def.name))
#    1936 if node_def.device:
#    1937   pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:
